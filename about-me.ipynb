# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Shyam Sunder Chiliveri"
reason = "I'm bridging Materials Science and AI - using Deep Learning to analyze microscopy images, predict material properties with 90%+ accuracy, and automate quality control. My journey from examining steel fractures under electron microscopes to building CNN pipelines has shown me how AI can revolutionize engineering"
fun_fact = "I built a RAG system that queries 13,400+ ISO/DIN standards in 2-5 seconds! My goal for this course: master MLOps and deploy production-ready AI solutions that transform manufacturing"

print(f"Hi! My name is {name}. I’m excited to learn because {reason}. A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Shyam Sunder Chiliveri. I’m excited to learn because I'm bridging Materials Science and AI - using Deep Learning to analyze microscopy images, predict material properties with 90%+ accuracy, and automate quality control. My journey from examining steel fractures under electron microscopes to building CNN pipelines has shown me how AI can revolutionize engineering. A fun fact about me is: I built a RAG system that queries 13,400+ ISO/DIN standards in 2-5 seconds! My goal for this course: master MLOps and deploy production-ready AI solutions that transform manufacturing.
